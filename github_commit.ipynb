# %%
# 구글 드라이브 Mount
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
# github와 연동하고 싶은 폴더로 이동
# %cd '/content/drive/MyDrive/혼공머신러닝,딥러닝'
# Out:
# /content/drive/MyDrive/혼공머신러닝,딥러닝

# %%
# git 생성
# !git init
# !git config --global user.email "drlaalswl7288@gmail.com"
# !git config --global user.name "12L-zl"
# !git branch -M main
# Out:
# Reinitialized existing Git repository in /content/drive/MyDrive/혼공머신러닝,딥러닝/.git/

# %%
# github 연동
# !git remote set-url origin https://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@github.com/12L-zl/ML-DL-BASIC.git

# %%
# git commit
# !git add .
# !git commit -m "commit"

# %%
# git push
# !git push origin main
# Out:
# To https://github.com/12L-zl/ML-DL-BASIC.git
#  ! [rejected]        main -> main (non-fast-forward)
# error: failed to push some refs to 'https://github.com/12L-zl/ML-DL-BASIC.git'
# hint: Updates were rejected because the tip of your current branch is behind
# hint: its remote counterpart. Integrate the remote changes (e.g.
# hint: 'git pull ...') before pushing again.
# hint: See the 'Note about fast-forwards' in 'git push --help' for details.

# %%
# !git config pull.rebase false

# %%
# !git pull origin main --allow-unrelated-histories
# Out:
# From https://github.com/12L-zl/ML-DL-BASIC
#  * branch            main       -> FETCH_HEAD
# <ve/MyDrive/혼공머신러닝,딥러닝/.git/MERGE_MSG" 6L, 287B▽  Pzz\[0%m           [>cMerge branch 'main' of https://github.com/12L-zl/ML-DL-BASIC
# # Please enter a commit message to explain why this merge is necessary,# especially if it merges an updated upstream into a topic branch.#
# # Lines starting with '#' will be ignored, and an empty message aborts
# # the commit.
# ...
